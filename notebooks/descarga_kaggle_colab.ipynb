# %% [markdown]
# # Descarga de Datos de Kaggle Directamente en Colab
#
# Este notebook te ahorrará descargar los 3GB en tu PC local. Usaremos tu nuevo Token de API para descargar el dataset directamente aquí.
#
# ### Paso 1: Configurar el Token de Kaggle
# Pega el token que te acaba de dar Kaggle en la variable `os.environ['KAGGLE_API_TOKEN']` en la siguiente celda y ejecútala.

# %%
import os

# Reemplaza el string con tu token real si es diferente
os.environ['KAGGLE_API_TOKEN'] = ""

print("Token configurado correctamente.")
# Out:
# Token configurado correctamente.

# %% [markdown]
# ### Paso 2: Descargar y descomprimir el dataset
# Ejecuta la siguiente celda. Colab usará tu token para descargar los 3GB en segundos y descomprimirlos.

# %%
# !pip install -q kaggle

# Descargar el dataset oficial usando el identificador de Kaggle
print("Descargando el dataset...")
# !kaggle datasets download -d arafatsahinafridi/multi-class-driver-behavior-image-dataset

# Descomprimir los datos (la bandera -q es para que no llene la pantalla de texto)
print("Descomprimiendo el dataset... (esto puede tomar 1-2 minutos)")
# !unzip -q multi-class-driver-behavior-image-dataset.zip -d /content/driver_behavior_dataset

print("¡Listo! Los datos están en la carpeta '/content/driver_behavior_dataset'")
# Out:
# Descargando el dataset...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\JUAN_JOSE\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Descomprimiendo el dataset... (esto puede tomar 1-2 minutos)
# Traceback (most recent call last):
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\JUAN_JOSE\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts\kaggle.exe\__main__.py", line 5, in <module>
# ...

# %% [markdown]
# ### Paso 3: ¡Entrenar!
# Ahora ya puedes iniciar el entrenamiento apuntando a la ruta donde acabamos de descomprimir los datos.

# %%
# Importante: asegúrate de cambiar DATA_DIRECTORY a '/content/driver_behavior_dataset' en tu código train.py 
# O puedes simplemente copiar y pegar el código de train.py en celdas debajo de esta para entrenar aquí mismo.
